# %%
figsize(8,6)

# %%
from itertools import chain

# %%
from scipy.signal import hilbert
from scipy.ndimage import gaussian_filter
from scipy.optimize import curve_fit
from scipy.spatial import distance, Delaunay, Voronoi #, cKDTree, KDTree

# %%
import orientation as orient
import correlation as corr
reload(orient)
reload(corr)
import otracks
from glob import glob
import os

# %%
tau = 2*np.pi

# %%
loc = "../orientation/"
prefix = "equilibrium"
ns = np.unique([int(c[1:]) for f in glob(loc+prefix+'*') for c in f.split('_') if c.startswith('n')])
ns
# Out:
# array([256, 272, 288, 304, 320, 328, 336, 344, 352, 360, 368, 376, 384,
#        392, 400, 408, 416, 432, 448])

# %%
alldata = {n: dict(zip(['data','cdata','odata','omask'],
                       otracks.load_from_npz(loc+prefix+'_n'+str(n))))
           for n in ns}

# %% [markdown]
# ###Confirmation of data

# %%
for n, d in sorted(alldata.iteritems())[::2]:
    frames = np.unique(d['data']['f'])
    for f in frames[3:4]:
        mask = (d['data']['f']==f) & d['omask']
        orient.plot_orient_quiver(d['data'], d['odata'], mask, None)

# %% [markdown]
# ###Check distribution of particle orientations.
# Histogram of all orientations modulo 90°, where the angle is measured perpendicular to the most common orientation

# %%
for n, d in sorted(alldata.iteritems()):
    bins = 16
    h = np.zeros(bins)
    frames = np.unique(d['data']['f'])#[1:]
    for f in frames:
        masks = (d['data']['f']==f) & d['omask']
        hf, b = np.histogram(d['odata']['orient'][masks]%(tau/4), density=True, range=(0,tau/4), bins=bins)
        r = hf.argmax()
        #r = np.dot(hf, b[:-1])/hf.sum()
        #r = np.abs(b[:-1] - r).argmin()
        h += np.roll(hf, hf.size/2 - r)
    h /= frames.size
    plt.step(b[1:], h, label=str(n/500.), c=cm.jet(n/500.), lw=3, where='pre')
plt.xlim(0, tau/4 + .1)
plt.legend()
plt.xlabel(r'particle angle $\theta$')

# %%
for n, d in sorted(alldata.iteritems()):
    bins = 20
    #h = np.zeros(bins)
    frames = np.unique(d['data']['f'])#[1:]
    th_all = []
    for f in frames:
        masks = (d['data']['f']==f) & d['omask']
        ths = d['odata']['orient'][masks]%(tau/4)
        th0 = np.angle(np.mean(np.exp(4*ths*1j)))%(tau/4)
        th_all.extend((ths-th0)%(tau/4))
    #h, b = np.histogram(th_all, density=True, range=(0,tau/4), bins=bins)
    #plt.step(b[:-1], h, label=str(n/500.), c=cm.jet(n/500.), lw=3, where='post')
    plt.hist(th_all, bins, (0,tau/4), True, lw=3, label=str(n/500.), color=cm.jet(n/500.), histtype='step')
plt.xlim(0, tau/4)
plt.legend(loc='lower right')
plt.xlabel(r'particle angle $\theta$')
savefig('angle_hist.png')

# %%
from scipy.spatial import Voronoi

def get_neighbors(v, p, pm=None):
    """ give neighbors in voronoi tessation v of point id p
        if already calculated, pm is point mask
    """
    if pm is None:
        pm = vor.ridge_points == p
    else:
        pm = pm[p]
    pts = v.ridge_points[np.any(pm, 1)]
    return pts[pts != p]

# %%
# %%prun
bins = 50
locphi = []
gs = []
for n, d in sorted(alldata.iteritems()):
    frames = np.unique(d['data']['f'])[::10]
    dorient = []
    locphi_n = []
    g = []
    for f in frames:
        masks = (d['data']['f']==f) & d['omask']
        pts = d['data'][masks][['x','y']].view((float,2))
        orients = d['odata']['orient'][masks]
        assert pts.shape == (masks.sum(), 2)
        vor = Voronoi(pts)
        pairs = vor.ridge_points
        dorient.extend(corr.dtheta(*orients[pairs].T))
        phi_neigh = np.abs([np.mean(np.exp(4*orients[get_neighbors(vor, i)]*1j)) for i in range(masks.sum())])
        locphi_nf = np.abs(np.mean(phi_neigh))
        locphi_n.append(locphi_nf)
        phif = corr.local_particle_orientational(orients, vor)
        diffs,  = corr.orient_corr(pts, orients)
        g.append(gf)
    locphi.append(np.mean(locphi_n))
    plt.figure(1)
    plt.plot(np.mean(g, 0), color=cm.jet(n/500.))
    plt.figure(2)
    plt.hist(dorient, bins, (0,tau/8), True, histtype='step', label=str(n/500.), color=cm.jet(n/500.), lw=3)
plt.figure(2)
plt.legend(loc='best')
plt.title('orientation differences between delaunay neighbors')
plt.xlabel('angle difference (radian)')
plt.savefig('odiff_delaunay.png')
plt.figure()
plt.title(r'mean of local $\varphi_4$')
plt.xlabel('particle density')
plt.ylim(0,1)
plt.plot(ns/500., locphi, 'o')
plt.savefig('local_phi_4.png')
plt.figure(1)
plt.title('$g_m(r)$')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/_methods.py:57: RuntimeWarning: invalid value encountered in cdouble_scalars

# %%
bins = 50
locphi = []
for n, d in sorted(alldata.iteritems()):
    frames = np.unique(d['data']['f'])[1:]
    dorient = []
    locphi_n = []
    for f in frames:
        masks = (d['data']['f']==f) & d['omask']
        pts = d['data'][masks][['x','y']].view((float,2))
        orients = d['odata']['orient'][masks]
        assert pts.shape == (masks.sum(), 2)
        vor = Voronoi(pts)
        pairs = vor.ridge_points
        dorient.extend((np.subtract(*(orients[pairs].T))%(tau/4)))
        phi_neigh = np.abs([np.mean(np.exp(4*orients[get_neighbors(vor, i)]*1j)) for i in range(masks.sum())])
        locphi_nf = np.abs(np.mean(phi_neigh))
        locphi_n.append(locphi_nf)
    locphi.append(np.mean(locphi_n))
    #plt.hist(dorient, bins, (-tau/4,tau/4), True, histtype='step', label=str(n/500.), color=cm.jet(n/500.), lw=3)
#plt.legend(loc='best')
#plt.title('orientation differences between delaunay neighbors')
#plt.xlabel('angle difference (radian)')
#plt.savefig('odiff_delaunay.png')
#plt.figure()
#plt.title(r'mean of local $\varphi_4$')
#plt.xlabel('particle density')
#plt.ylim(0,1)
#plt.plot(ns/500., locphi, 'o')
#plt.savefig('local_phi_4.png')

# %%
d = distance.pdist(points)

# %% [markdown]
# For a global measure of orientational order across the entire disk, we can measure the order parameter for particle orientation, given by $\Phi_m = \langle e^{im\theta}\rangle$, average is over all particles in a given frame.  This leaves us with a complex value with an arbitrary phase.  To obtain the full average, we take the magnitude of $\Phi_m$ and average that over all frames for a given density.

# %%
ns, phis, phierr = zip(*[chain.from_iterable(([n], corr.global_particle_orientational(d['odata'][d['omask'] & (d['data']['f']==f)]['orient'])))
                       for n, d in alldata.iteritems() for f in np.unique(d['data']['f'])[1:]])
ns, phis, phierr = map(np.array, [ns, phis, phierr])
phis, phierr = np.array([[np.abs(phis[ns==n]).mean(),
                          np.sqrt(phierr[ns==n].mean()**2 + (phis[ns==n].std()/(ns==n).sum())**2)]
                         for n in np.unique(ns)]).T
ns = np.unique(ns)

# %%
#plot(ns.real/500., phis.real, '+', label='real')
#plot(ns.real/500., phis.imag, '.', label='imag')
plot(ns.real/500., phis, 'o', label='abs')
errorbar(ns.real/500., phis, phierr, fmt=None, ecolor='b')
#plot(ns.real, np.angle(phis), '.', label='ang')
legend()
title("Global particle orientation parameter")
xlabel("density")

# %%
stds = []
errs = []
for n, d in sorted(alldata.iteritems()):
    frames = np.unique(d['data']['f'])#[1:]
    nstd = []
    for f in frames:
        masks = (d['data']['f']==f) & d['omask']
        nstd.append(np.std(d['odata']['orient'][masks]%(tau/4))/np.sqrt(mask.sum()))
    stds.append(np.mean(nstd))
    errs.append(np.std(nstd)/np.sqrt(len(nstd)))
plot(ns, stds)
errorbar(ns, stds, errs)
# Out:
# <Container object of 3 artists>

# %%
decays = {'exp': corr.exp_decay, 'pow': corr.powerlaw,}# 'log': corr.log_decay}

# %% [markdown]
# To determine the extent of translational order, we measure the pair correlation function $g(r)$.  This is implemented as a weighted histogram of the distances between all pairs of particles.  The amplitude envelope of $g(r)$ gives a decay shape and length scale, which we can use to quantify the range of the ordering.  To obtain the envelope, we apply a Hilbert transform to the curve after removing

# %%
for n, d in sorted(alldata.iteritems()):
    dr = .05 #in particle units
    gs, rgs = corr.build_gs(d['data'], None, 1, dr=dr)
    g, dg, rg = corr.avg_hists(gs, rgs)
    g = g[rg>92]
    rg = rg[rg>92]
    # convert pixels to squares:
    r = rg/92.
    #x = r - 1

    #gm = np.convolve(g, np.ones(2/dr)*dr/2., 'same')
    #h = corr.apply_hilbert(g, 1/dr, )#full=True)
    step(r, g, ls='-', where='pre', label=str(n/500.), color=cm.jet(n/500.), lw=1)
    #plot(r, h, color=cm.jet(n/500.), lw=2,)# label='hilbert')
    #plot(r, g, '.')
    #plot(r, gm, label='moving avg')
    #plot(r, gm+h.real, label='real')
    #plot(r, gm+h.imag, label='imag')
    #plot(r, h*h.conj(), label='sqr'
    #errorbar(r, g, color=cm.jet(n/500.))
    #print n/500.
    #w = np.sqrt(h*r)
    #plot(r, w*.1, ':', label='weight')
    #for name, decay in decays.iteritems():
    #    p, cov = curve_fit(decay, x, h, (1., 1., 0), sigma=w)
    #    plot(r, decay(x, *p), label=name)
    #    resid = (h - decay(x, *p))
    #    chi2 = np.dot(resid, resid)
    #    print '\t', name, "length: {:.3f}, amplitude: {:.3f}, offset: {:.3f}".format(*p),\
    #          ", chi^2: {:.3e}".format(chi2)

#A, A0 = .025, .003
#T, T0 = 2., 1.
#W = 2*np.pi * .000000001
#plot(rg/92., A0 + A*np.exp((T0-r)/T)*np.cos(W*r))
legend(loc='best', ncol=2)
title("Pair correlation function $g(r)$")
xlabel("$r/s$")
savefig("../writing/g_r_equilibrium.pdf")#, dpi=100)
#xlim(0.9, 1.1)

# %%
print np.mean([np.max([alldata[n]['data']['x'].max() for n in alldata.iterkeys()]) \
                 - np.min([alldata[n]['data']['x'].min() for n in alldata.iterkeys()]),
               np.max([alldata[n]['data']['y'].max() for n in alldata.iterkeys()])\
                 - np.min([alldata[n]['data']['y'].min() for n in alldata.iterkeys()])]
              )/2 + 92
# Out:
# 1256.3675

# %% [markdown]
# To determine the extent of particle orientational order, we use the $m$-fold particle orientational correlation function, which is given by $g_m(r) = \langle \cos[m (\theta_r - \theta_0 )] \rangle$, where the average is over all pairs of particles separated by distance between $r$ and $r + dr$, where $dr$ is implemented as ``binsize`` below.  Hilbert transform is also applied

# %%
ss = 92.
rmax = 10*ss # r of dish is ~13.6
dr = ss*.1
rs = np.arange(0, rmax, dr)
for n, d in sorted(alldata.iteritems()):
    fs = np.unique(d['data']['f'])
    gr = np.empty(fs.shape+rs.shape, float)
    for f in fs:
        mask = (d['data']['f']==f)&d['omask']
        positions = d['data'][mask][['x','y']].view((float,2))
        dists, od = corr.orient_corr(positions, d['odata']['orient'][mask], m=4, rmax=rmax)
        for i, r in enumerate(rs):
            rmask = np.abs(dists-r) < dr
            gr[f,i] = np.mean(od[rmask])
    gr = gr.mean(0)
    figure(1)
    plot(rs/ss, gr, label=str(n/500.), color=cm.jet(n/500.))
    
    figure(2)
    gr[gr<=0] = np.nan
    loglog(rs/ss, gr, label=str(n/500.), color=cm.jet(n/500.))

figure(1)
title(r'Particle orientation correlation $g_4(r)$')
xlabel('$r/s$')
xlim(0, rmax/ss)
ylim(-.1, 1)
#legend(loc='best', ncol=2)
savefig("../writing/g4_r.pdf")

figure(2)
ylim(1e-2, 1)
xlim(1, rmax/ss)
#legend(loc='best', ncol=2)
savefig("../writing/g4_r_loglog.pdf")
